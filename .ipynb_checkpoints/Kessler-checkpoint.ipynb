# %%
import rebound
import numpy as np
import re
import skyfield.sgp4lib as spg4
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-b50b21f54792> in <module>()
# ----> 1 import rebound
#       2 import numpy as np
#       3 import re
#       4 import skyfield.sgp4lib as spg4
#       5 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named rebound

# %% [markdown]
# https://en.wikipedia.org/wiki/Two-line_element_set#cite_note-nasahelp-12
#
# https://spaceflight.nasa.gov/realdata/sightings/SSapplications/Post/JavaSSOP/SSOP_Help/tle_def.html
#
# https://digitalcommons.calpoly.edu/cgi/viewcontent.cgi?referer=https://en.wikipedia.org/&httpsredir=1&article=1094&context=theses

# %%
class two_line_element:
    
    def __init__(self, data):
        self.parse_data(data)
        
    def parse_data(self, satelite_data):
        self.title = satelite_data[0]
        line_one = satelite_data[1].split()
        line_two = satelite_data[2].split()

        self.catalog_number = re.search('[0-9]{1,5}', line_one[0]).group()
        self.classification = re.search('[UCS]', line_one[0]).group()

        international_designator = re.search('([0-9]{2})([0-9]{3})(\w{1,3})', line_one[1])
        self.launch_year = international_designator.group(1)
        self.launch_number = international_designator.group(2)
        self.launch_piece =  international_designator.group(3)

        epoch = re.search('([0-9]{2})(\d+\.\d+)', line_one[2])
        self.epoch_year = epoch.group(1)
        self.epoch_day = epoch.group(2)

        self.ballistic_coefficient = float(line_one[3])
        self.mean_motion_double_prime = line_one[4]
        self.BSTAR = line_one[5]

        self.inclination = line_two[1]
        self.right_ascension_of_ascending_node = line_two[2]
        self.eccentricity = line_two[3]
        self.argument_of_perigee = line_two[4]

        mean_anomaly = line_two[5]
        
        spg4.io

#         revolution = re.search('([0-9]{2}\.[0-9]{8})([0-9]{5})', line_two[6])
#         self.mean_motion = revolution.group(1)
#         self.revolution_number_at_epoch = revolution.group(2)

# %% [markdown]
# https://www.space-track.org
#
# https://www.celestrak.com/NORAD/documentation/spacetrk.pdf

# %%
# Opening the .txt file
with open("3le-clean.txt") as f:
    txt = f.read()
    
# Listing all of the coordinates for latitude and longitude that are found in the .txt file
# using regular expressions

# %%
sat_lines = re.findall('(.*?)\n(.*?)\n(.*?)\n', txt)

def to_earth_satellite(lines):
    title = lines[0]
    line1 = lines[1]
    line2 = lines[2]
    return spg4.EarthSatellite(line1, line2, name=title)

satellites = [to_earth_satellite(lines) for lines in sat_lines]

sat_names = [sat.name for sat in satellites]
iss_index = sat_names.index("0 ISS (ZARYA)")
iss = satellites[iss_index]

# %%
from skyfield.api import load, EarthSatellite

planets = load('de421.bsp')

# %%
earth = planets["Earth"]
print(earth)
# Out:
# Sum of 2 vectors:
#  + Segment 'de421.bsp' 0 SOLAR SYSTEM BARYCENTER -> 3 EARTH BARYCENTER
#  + Segment 'de421.bsp' 3 EARTH BARYCENTER -> 399 EARTH

# %%
def makecubelimits(axis, centers=None, hw=None):
    lims = ax.get_xlim(), ax.get_ylim(), ax.get_zlim()
    if centers == None:
        centers = [0.5*sum(pair) for pair in lims] 

    if hw == None:
        widths  = [pair[1] - pair[0] for pair in lims]
        hw      = 0.5*max(widths)
        ax.set_xlim(centers[0]-hw, centers[0]+hw)
        ax.set_ylim(centers[1]-hw, centers[1]+hw)
        ax.set_zlim(centers[2]-hw, centers[2]+hw)
        print("hw was None so set to:", hw)
    else:
        try:
            hwx, hwy, hwz = hw
            print("ok hw requested: ", hwx, hwy, hwz)

            ax.set_xlim(centers[0]-hwx, centers[0]+hwx)
            ax.set_ylim(centers[1]-hwy, centers[1]+hwy)
            ax.set_zlim(centers[2]-hwz, centers[2]+hwz)
        except:
            print("nope hw requested: ", hw)
            ax.set_xlim(centers[0]-hw, centers[0]+hw)
            ax.set_ylim(centers[1]-hw, centers[1]+hw)
            ax.set_zlim(centers[2]-hw, centers[2]+hw)

    return centers, hw

def deriv(X, t):
    x, v = X.reshape(2, -1)
    acc = -GMe * x * ((x**2).sum())**-1.5
    return np.hstack((v, acc))

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint as ODEint
from mpl_toolkits.mplot3d import Axes3D

halfpi, pi, twopi = [f*np.pi for f in (0.5, 1, 2)]
degs, rads = 180/pi, pi/180

km  = 0.001
GMe = 3.986E+14 # m^3/s^2
Re  = 6378137.  # meters
alt = 1E+06     # meters
a   = Re + alt
T   = twopi * np.sqrt(a**3/GMe)

v0  = np.sqrt(GMe/a)
incdegs = 57.

inc = rads * incdegs
cinc, sinc = [f(inc) for f in (np.cos, np.sin)]

X0 = np.array([Re+alt, 0, 0] + [0, cinc*v0, sinc*v0])

print(f'period {T} seconds or {T/60} minutes')
print(f'inclination {incdegs} degrees')
print(f'initial position {km * X0[:3]} km')
print(f'initial velocity {X0[3:]} m/s')
print(f'initial speed {v0} m/s')

times = np.linspace(0, T, 201)

answer, info = ODEint(deriv, X0, times, full_output=True)


theta = np.linspace(0, twopi, 201)
cth, sth, zth = [f(theta) for f in (np.cos, np.sin, np.zeros_like)]
lon0 = Re*np.vstack((cth, zth, sth))
lons = []
for phi in rads*np.arange(0, 180, 15):
    cph, sph = [f(phi) for f in (np.cos, np.sin)]
    lon = np.vstack((lon0[0]*cph - lon0[1]*sph,
                     lon0[1]*cph + lon0[0]*sph,
                     lon0[2]) )
    lons.append(lon)

lat0 = Re*np.vstack((cth, sth, zth))
lats = []
for phi in rads*np.arange(-75, 90, 15):
    cph, sph = [f(phi) for f in (np.cos, np.sin)]
    lat = Re*np.vstack((cth*cph, sth*cph, zth+sph))
    lats.append(lat)

if True:
    fig = plt.figure(figsize=[10, 8])  # [12, 10]

    ax  = fig.add_subplot(1, 1, 1, projection='3d')

    x, y, z = answer.T[:3]
    ax.plot(km*x, km*y, km*z)
    for x, y, z in lons:
        ax.plot(km*x, km*y, km*z, '-k')
    for x, y, z in lats:
        ax.plot(km*x, km*y, km*z, '-k')

    centers, hw = makecubelimits(ax)

    print("centers are: ", centers)
    print("hw is:       ", hw)
    plt.show()
# Out:
# period 6307.122902037862 seconds or 105.11871503396438 minutes
# inclination 57.0 degrees
# initial position [7378.137    0.       0.   ] km
# initial velocity [   0.         4003.17019194 6164.34152276] m/s
# initial speed 7350.1345562458455 m/s
# hw was None so set to: 8115.951438943057
# centers are:  [-0.00011361183214830817, 0.0, 0.0]
# hw is:        8115.951438943057

# %% [markdown]
# ## NASA Breakup Model
#
# FOUND IMPLEMENTATION:
# https://gitlab.obspm.fr/apetit/nasa-breakup-model/tree/master
#
#
# Nf = The number of produced fragments
#
# Me = Reference Mass
#
# Lc = characteristic length of the fragment
#
# $$
# Nf (Lc[m]) = 0.1(M_{e})^{0.75} L_{c}^{-1.71}
# $$

# %%
# l_characteristic = Characteristic length
# v_impact = relative impact velocity
# m_target = Mass Target
# m_projectile = Mass Projectile

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform
import random


# Helper functions
def mean_value_AM(lambda_c):
    if lambda_c <= -1.75: 
        return -0.3
    elif -1.75 < lambda_c and lambda_c < -1.25:
        return -0.3 - (1.4*(lambda_c + 1.75))
    else:
        return -1.0
    
def standard_dev_AM(lambda_c):
    if lambda_c <= -3.5:
        return 0.2
    else:
        return 0.2 + (0.1333*(lambda_c + 3.5))
    
##
## Computes the average corss sectional area as a function of L_c
##
def mean_area(L_c):
    if L_c < 0.00167: # (meters)
        return 0.540424 * L_c**2
    else:
        return 0.556945 * L_c**2.0047077

# Distributions
def normal_distribution_function(mu_am, sd_am, X):
    return (1/(np.sqrt(np.pi * 2) * sd_am)) * np.exp(-1 * ((X-mu_am)**2/(2*sd_am**2)))
    
def distribution_AM(lambda_c, X):
    mu_am = mean_value_AM(lambda_c)
    sd_am = standard_dev_AM(lambda_c)
    return normal_distribution_function(mu_am, sd_am, X)

distribution_Mass = lambda AM, A: A/AM

# Functions
def number_fragments(l_characteristic, m_target, m_projectile, v_impact, is_catastrophic):
    # Defining reference Mass
    m_ref = 0
    if is_catastrophic: m_ref = m_target + m_projectile
    else: m_ref = m_projectile * (v_impact)**2
    
    return 0.1 * (m_ref)**0.75 * (l_characteristic)**(-1.71)

# Verifying mean of A/M distribution: (Currently matches for Small Obj, pg 209)
L_c = np.linspace(0, 1, 100)
lambda_c = np.log10(L_c)
mu = [mean_value_AM(lam_c) for lam_c in lambda_c]
plt.plot(L_c, mu, color="g")
plt.ylim(-1.5, 0)
plt.yticks(np.arange(-1.5, 0.5, 0.5))
plt.xticks(np.arange(0, 1.2, 0.2))
plt.ylabel("$\mu$")
plt.xlabel("$L_{c}[M]$")
plt.title("Small Object A/M $\mu$ distribution")
plt.show()

# Verifying varience of A/M distribution:
L_c = np.linspace(0, 1, 100)
lambda_c = np.log10(L_c)
mu = [standard_dev_AM(lam_c) for lam_c in lambda_c]
plt.plot(L_c, mu, color="g")
plt.yticks(np.arange(0, 1.2, 0.2))
plt.xticks(np.arange(0, 1.2, 0.2))
plt.ylabel("$\sigma$")
plt.xlabel("$L_{c}[M]$")
plt.title("Small Object A/M $\sigma$ distribution")
plt.show()

# Verifying fragment numbers:
L_c = np.geomspace(0.001, 0.1, 100)
fragments = [number_fragments(l, 1000, 10, 10, True) for l in L_c]
plt.plot(np.log10(L_c), fragments)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,1))
plt.show()

# # Checking counts 
# i = np.argmax(L_c > 0.001)
# print(np.sum(fragments))

average = 0
for x in range(10000):
    choice = random.choice(L_c)
    val = number_fragments(choice, 1000, 10 , 10, True)
    average += val
    
print(average/10000)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in log10
# 312495.430743798
